# %% [markdown]
# ##### install yasa

# %%
# !pip install --upgrade yasa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yasa
#   Downloading yasa-0.6.2.tar.gz (33.8 MB)
#      |████████████████████████████████| 33.8 MB 1.2 MB/s
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from yasa) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from yasa) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yasa) (1.3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from yasa) (3.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from yasa) (0.11.2)
# Collecting mne>=0.23
#   Downloading mne-1.1.1-py3-none-any.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 21.0 MB/s
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from yasa) (0.56.2)
# Collecting outdated
#   Downloading outdated-0.2.1-py3-none-any.whl (7.5 kB)
# Collecting antropy
#   Downloading antropy-0.1.4.tar.gz (16 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from yasa) (1.0.2)
# Collecting tensorpac>=0.6.5
#   Downloading tensorpac-0.6.5-py3-none-any.whl (423 kB)
#      |████████████████████████████████| 423 kB 38.6 MB/s
# Collecting pyriemann>=0.2.7
#   Downloading pyriemann-0.3.tar.gz (365 kB)
#      |████████████████████████████████| 365 kB 41.6 MB/s
# Collecting sleepecg>=0.5.0
#   Downloading sleepecg-0.5.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.1 MB/s
# Collecting lspopt
#   Downloading lspopt-1.2.0-py2.py3-none-any.whl (35 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from yasa) (7.7.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from yasa) (1.1.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.7/dist-packages (from mne>=0.23->yasa) (1.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from mne>=0.23->yasa) (4.64.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from mne>=0.23->yasa) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from mne>=0.23->yasa) (2.11.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mne>=0.23->yasa) (21.3)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne>=0.23->yasa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne>=0.23->yasa) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mne>=0.23->yasa) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.23->yasa) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.23->yasa) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.23->yasa) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.23->yasa) (2022.6.15)
# Collecting requests>=2.19.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Requirement already satisfied: PyYAML>=5.4.0 in /usr/local/lib/python3.7/dist-packages (from sleepecg>=0.5.0->yasa) (6.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.23->yasa) (2.1.1)
# Collecting stochastic
#   Downloading stochastic-0.6.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 6.1 MB/s
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (3.0.3)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (7.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (5.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (0.2.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->yasa) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->yasa) (5.1.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (2.6.1)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 47.0 MB/s
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (57.4.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->yasa) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->yasa) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->yasa) (1.15.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->yasa) (5.3.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.13.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (5.6.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (4.11.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (1.8.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (5.4.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->yasa) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->yasa) (23.2.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->mne>=0.23->yasa) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->yasa) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->yasa) (1.4.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib->yasa) (4.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (5.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.7.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (2.16.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (22.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (4.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (3.8.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.5.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->yasa) (0.39.1)
# Collecting littleutils
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yasa) (2022.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->yasa) (3.1.0)
# Building wheels for collected packages: yasa, pyriemann, antropy, littleutils
#   Building wheel for yasa (setup.py) ... done
#   Created wheel for yasa: filename=yasa-0.6.2-py3-none-any.whl size=33797167 sha256=9881dffd68b5646609385814098e21b28aea014b9ed61fc79294dbdef208baa3
#   Stored in directory: /root/.cache/pip/wheels/52/8c/9c/1352fced5b6240ed1e3669f477d7ce0e2fe693e28b7bcc45f4
#   Building wheel for pyriemann (setup.py) ... done
#   Created wheel for pyriemann: filename=pyriemann-0.3-py2.py3-none-any.whl size=78033 sha256=c8c73e6301dcdab693a0d5dc80e21ff2fc9770cb33bf2a8740c7674258ac2aef
#   Stored in directory: /root/.cache/pip/wheels/0b/1b/bf/a537f9e17e6c3490004ede419c72f863af1d0d765d25e532ef
#   Building wheel for antropy (setup.py) ... done
#   Created wheel for antropy: filename=antropy-0.1.4-py3-none-any.whl size=16159 sha256=9257a3fb2e7b73892d85a5fe3e6af8deb6c1ff14bc7bc3fac038970d6f2583fe
#   Stored in directory: /root/.cache/pip/wheels/d4/cc/6b/28fa7036bdabc6f1f92fd6a108ae259dbb48f107f676d6b491
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7048 sha256=3ac5d10e541315b254c9de6d326fb5b3942b8ca696aa2738825808fbcc9b907e
#   Stored in directory: /root/.cache/pip/wheels/d6/64/cd/32819b511a488e4993f2fab909a95330289c3f4e0f6ef4676d
# Successfully built yasa pyriemann antropy littleutils
# Installing collected packages: jedi, requests, stochastic, littleutils, tensorpac, sleepecg, pyriemann, outdated, mne, lspopt, antropy, yasa
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed antropy-0.1.4 jedi-0.18.1 littleutils-0.2.2 lspopt-1.2.0 mne-1.1.1 outdated-0.2.1 pyriemann-0.3 requests-2.28.1 sleepecg-0.5.0 stochastic-0.6.0 tensorpac-0.6.5 yasa-0.6.2

# %% [markdown]
# # Artifact rejection
#
# This notebook demonstrates how to perform automatic artifact rejection in YASA, specifically to detect major body movements on single or multi-channel data.
#
# Please make sure to install the latest version of YASA first with: `pip install --upgrade yasa`
#
# To start with, let's load a full night recording of EEG data (9 channels), sampled at 100 Hz and staged.

# %%
#구글드라이브 공유폴더에서 불러오기
# !gdown --id 1kCK9f1misI54m8SdJIC94OUBcE4-k9dB --output 04_data_full_6hrs_100Hz_9channels.npz
# !gdown --id 1scqMWfHpqdXQ4tyPfmfgTelHxh0xXg0J --output 05_data_full_6hrs_100Hz_hypno.npz
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1kCK9f1misI54m8SdJIC94OUBcE4-k9dB
# To: /content/04_data_full_6hrs_100Hz_9channels.npz
# 100% 37.8M/37.8M [00:00<00:00, 40.2MB/s]
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1scqMWfHpqdXQ4tyPfmfgTelHxh0xXg0J
# To: /content/05_data_full_6hrs_100Hz_hypno.npz
# 100% 8.99k/8.99k [00:00<00:00, 9.95MB/s]

# %%
import yasa
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', font_scale=1.2)

# Load data
f = np.load('/content/04_data_full_6hrs_100Hz_9channels.npz')
data= f['data']
chan = ['Fz', 'F3', 'F4', 'Cz', 'C3', 'C4', 'Pz', 'P3', 'P4']
sf = 100.
hypno = np.load('/content/05_data_full_6hrs_100Hz_hypno.npz').get('hypno')
times = np.arange(data.size) / sf

print(data.shape)
print(chan)
print(np.round(data[:, 0:5], 3))
# Out:
# (9, 2161058)
# ['Fz', 'F3', 'F4', 'Cz', 'C3', 'C4', 'Pz', 'P3', 'P4']
# [[20.963 30.527 45.829 29.15  31.751]
#  [ 1.527 12.594 37.552 11.296 16.334]
#  [15.797 22.307 39.922 25.657 27.094]
#  [28.573 39.195 48.994 33.361 37.699]
#  [-3.08   6.971 26.262  3.323  9.078]
#  [16.896 26.385 40.966 21.833 24.456]
#  [11.759 17.329 35.664 25.762 26.536]
#  [ 4.069 10.635 35.882 18.311 18.958]
#  [ 5.899 14.297 36.592 26.094 23.395]]

# %%
# For the sake of the example, let's add some flat data (e.g. disconnected) at the end
data = np.concatenate((data, np.zeros((data.shape[0], 20000))), axis=1)
hypno = np.concatenate((hypno, np.zeros(20000)))
data.shape, hypno.shape
# Out:
# ((9, 2181058), (2181058,))

# %%
# Plot hypnogram and spectrogram on Fz
# We should see a warning because of the flat data at the end
yasa.plot_spectrogram(data[0, :], sf, hypno);
# Out:
# /usr/local/lib/python3.7/dist-packages/yasa/plotting.py:239: RuntimeWarning: divide by zero encountered in log10
#   Sxx = 10 * np.log10(Sxx)  # Convert uV^2 / Hz --> dB / Hz

# %% [markdown]
# ***************
#
# ## 1. Artifact rejection without using the hypnogram
#
# ### 1.1. Covariance-based rejection
#
# The default method implemented in YASA is a multivariate approach based on covariance matrices. Briefly, the main idea of this approach is to estimate a reference covariance matrix of "clean data" $\bar{C}$ and reject every epoch which is too far from this reference covariance matrix. The distance of the covariance matrix of the current epoch $C$ from the reference matrix $\bar{C}$ is calculated using Riemannian geometry, which is more adapted than Euclidean geometry for symmetric positive definite covariance matrices:
#
# <center>$d = {\left( \sum_i \log(\lambda_i)^2 \right)}^{-1/2}$</center><br>
#
# where $\lambda_i$ are the joint eigenvalues of $C$ and $\bar{C}$. The epoch with covariance matric $C$ will be marked as an artifact if the distance $d$ is greater than a threshold $T$ (typically 2 or 3 standard deviations). $\bar{C}$ is iteratively estimated using a clustering approach. This function is essentially a wrapper around the [Potato class](https://pyriemann.readthedocs.io/en/latest/generated/pyriemann.clustering.Potato.html#pyriemann.clustering.Potato) in the pyRiemann library.
#
#
# **The pros of this approach are:**
#
# - Multivariate approach that takes into account the variance in each channel as well as the inter-relationship between all channels (covariance) to define artifacts
# - Robust to noise
#
# **The cons:**
#
# - Do not work with single-channel data. YASA requires at least 4 channels to use this method.
# - High computation time, especially with epochs smaller than 5-seconds, or very long datasets, or data with a very high sampling frequency (> 500 Hz). We recommend downsampling your data to 100 or 200 Hz prior to using this function.
# - Based on the assumption that most of the data is clean; otherwise the reference matrix will be biased. We recommend that you visually exclude any bad channels prior to using this function.
#
#
# **For more details please refer to**
#
# - Barachant, Andreev, & Congedo. (2013). [The Riemannian
#     Potato: an automatic and adaptive artifact detection method for online
#     experiments using Riemannian geometry](https://hal.archives-ouvertes.fr/hal-00781701/). *TOBI Workshop lV, 19–20.*
# - Barthélemy, Mayaud, Ojeda, & Congedo. (2019).
#     [The Riemannian Potato Field: A Tool for Online Signal Quality Index of
#     EEG](https://doi.org/10.1109/TNSRE.2019.2893113). *IEEE Transactions on Neural Systems and Rehabilitation Engineering:
#     27(2), 244–255.*
# - https://pyriemann.readthedocs.io/en/latest/index.html

# %%
art, zscores = yasa.art_detect(data, sf, window=5, method='covar', threshold=3)
art.shape, zscores.shape
# Out:
# ((4362,), (4362,))

# %%
# Art is an aray of 0 and 1, where 0 indicates a clean (or good epoch)  and 1 indicates an artifact epoch
print(art)
print(f'{art.sum()} / {art.size} epochs rejected.')
# Out:
# [False False False ...  True  True  True]
# 100 / 4362 epochs rejected.

# %%
# Plot the artifact vector
plt.plot(art);
plt.yticks([0, 1], labels=['Good (0)', 'Art (1)']);

# %% [markdown]
# **Plot the distribution of z-scores**

# %%
sns.distplot(zscores)
plt.title('Histogram of z-scores')
plt.xlabel('Z-scores')
plt.ylabel('Density')
plt.axvline(3, color='r', label='Threshold')
plt.axvline(-3, color='r')
plt.legend(frameon=False);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Given a threshold defined in the number of standard deviations from the mean, the proportion of samples that will be outside the range (e.g. rejected) is defined as $1 - \text{erf}\left ( \frac{z}{\sqrt{2}}\right )$. For more details, see https://en.wikipedia.org/wiki/Standard_deviation#Rules_for_normally_distributed_data

# %%
from scipy.special import erf
threshold = 3
perc_expected_rejected = (1 - erf(threshold / np.sqrt(2))) * 100
print(f'{perc_expected_rejected:.2f}% of all epochs are expected to be rejected.')
# Out:
# 0.27% of all epochs are expected to be rejected.

# %%
# Actual
(art.sum() / art.size) * 100
print(f'{(art.sum() / art.size) * 100:.2f}% of all epochs were actually rejected.')
# Out:
# 2.29% of all epochs were actually rejected.

# %% [markdown]
# **Merge the artifact vector with the hypnogram**

# %%
# The resolution of art is 5 seconds, so its sampling frequency is 1/5 (= 0.2 Hz)
sf_art = 1 / 5
art_up = yasa.hypno_upsample_to_data(art, sf_art, data, sf)
art_up.shape, hypno.shape
# Out:
# WARNING:yasa:Hypnogram is SHORTER than data by 0.58 seconds. Padding hypnogram with last value to match data.size.
# ((2181058,), (2181058,))

# %% [markdown]
# Now that `hypno` and `art_up` have the same size, we can easily merge them. Below, we mark as artifact (code = -1) all the 5-seconds epochs that were automatically rejected:

# %%
# Add -1 to hypnogram where artifacts were detected
hypno_with_art = hypno.copy()
hypno_with_art[art_up] = -1

# Proportion of each stage in ``hypno_with_art``
pd.Series(hypno_with_art).value_counts(normalize=True)
# Out:
#  2.0    0.431847
#  3.0    0.243036
#  4.0    0.216610
#  0.0    0.055325
#  1.0    0.030230
# -1.0    0.022951
# dtype: float64

# %%
# Plot new hypnogram and spectrogram on Fz
yasa.plot_spectrogram(data[0, :], sf, hypno_with_art);
# Out:
# /usr/local/lib/python3.7/dist-packages/yasa/plotting.py:239: RuntimeWarning: divide by zero encountered in log10
#   Sxx = 10 * np.log10(Sxx)  # Convert uV^2 / Hz --> dB / Hz

# %% [markdown]
# ### 1.2. Standard-deviation based rejection
#
# The second method implemented in YASA is a much faster and straightforward approach which is simply based on the distribution of the standard deviations of each epoch. Specifically, one first calculate the standard deviations of each epoch and each channel. Then, the resulting array of standard deviations is log-transformed and z-scored. Any epoch with one or more channel exceeding the threshold will be marked as artifact.
#
# Note that this approach is more sensitive to noise and/or the influence of one bad channel (e.g. electrode fell off at some point during the night). We therefore recommend that you visually inspect and remove any bad channels prior to using this function.

# %%
# Apply the artifact rejection with method='std'
# In order to have more details on the artifact rejection, one can set the
# logging level to INFO
art_std, zscores_std = yasa.art_detect(data, sf, window=5, method='std', threshold=3, verbose='info')
art_std.shape, zscores_std.shape
# Out:
# INFO:yasa:Number of samples in data = 2181058
# INFO:yasa:Sampling frequency = 100.00 Hz
# INFO:yasa:Data duration = 21810.58 seconds
# INFO:yasa:Trimmed standard deviation of CHAN000 = 20.6485 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN000 = 4660.3770 uV
# INFO:yasa:Trimmed standard deviation of CHAN001 = 17.9120 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN001 = 4069.6061 uV
# INFO:yasa:Trimmed standard deviation of CHAN002 = 23.5062 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN002 = 4851.8518 uV
# INFO:yasa:Trimmed standard deviation of CHAN003 = 27.3139 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN003 = 3987.3490 uV
# INFO:yasa:Trimmed standard deviation of CHAN004 = 20.1100 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN004 = 3914.2716 uV
# INFO:yasa:Trimmed standard deviation of CHAN005 = 21.0380 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN005 = 3805.6362 uV
# INFO:yasa:Trimmed standard deviation of CHAN006 = 19.9495 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN006 = 4169.8010 uV
# INFO:yasa:Trimmed standard deviation of CHAN007 = 20.3632 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN007 = 5292.4709 uV
# INFO:yasa:Trimmed standard deviation of CHAN008 = 22.7211 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN008 = 6208.8787 uV
# INFO:yasa:Number of channels in data = 9
# INFO:yasa:Number of samples in data = 2181058
# INFO:yasa:Sampling frequency = 100.00 Hz
# INFO:yasa:Data duration = 21810.58 seconds
# INFO:yasa:Number of epochs = 4362
# INFO:yasa:Artifact window = 5.00 seconds
# INFO:yasa:Method = std
# INFO:yasa:Threshold = 3.00 standard deviations
# INFO:yasa:Rejecting 39 epochs with >=50% of channels that are flat. Z-scores set to np.nan for these epochs.
# INFO:yasa:TOTAL: 129 / 4362 epochs rejected (2.96%)
# ((4362,), (4362, 9))

# %%
# When method='std', zscores is an array of shape (n_epochs, n_chan). 
# Notice the np.nan at the end of the data that corresponds to flat epochs
zscores_std
# Out:
# array([[-0.93850175, -1.03325305, -1.31413914, ..., -1.01438553,
#         -1.11122032, -1.11083162],
#        [-0.6637989 , -0.42282164, -1.1722693 , ..., -0.60194675,
#         -0.72830826, -0.62726795],
#        [-1.36069644, -1.16359489, -1.71304407, ..., -1.28683142,
#         -1.41654985, -1.37795803],
#        ...,
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan]])

# %%
# We can average the z-scores across all channels
avg_zscores = zscores_std.mean(-1)
avg_zscores
# Out:
# array([-1.03685734, -0.63156825, -1.34753832, ...,         nan,
#                nan,         nan])

# %%
# And check the distribution
sns.distplot(avg_zscores)
plt.title('Histogram of z-scores')
plt.xlabel('Z-scores')
plt.ylabel('Density')
plt.axvline(3, color='r', label='Threshold')
plt.axvline(-3, color='r')
plt.legend(frameon=False);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(f'The correlation between the two methods is r = {np.corrcoef(art, art_std)[0, 1]:.2f}')
# Out:
# The correlation between the two methods is r = 0.88

# %% [markdown]
# ***************
#
# ## 2. Artifact rejection with the hypnogram
#
# Sleep stages have very different EEG signatures, and the stage-agnostic artifact rejection that we've applied so far may incorrectly reject epochs that are simply belonging to a different sleep stage because the covariance matrices will look very different. A much better approach is to apply the artifact rejection on pre-staged data. In the section below, we demonstrate how tu run the artifact rejection with an hypnogram in order to apply the artifact rejection separately for each sleep stage.
#
# ### 2.1. Covariance-based rejection
#
# Concretely, what it means for the covariance-based method is that the reference covariance matrix will be estimated separately for each sleep stage, provided that at least 30 epochs of the current stage are present in data (which amounts to 2.5 minutes when using 5-seconds epochs).

# %%
art, zscores = yasa.art_detect(data, sf, window=5, hypno=hypno, include=(1, 2, 3, 4), 
                               method='covar', threshold=3, verbose='info')
art.shape, zscores.shape
# Out:
# INFO:yasa:Number of unique values in hypno = 5
# INFO:yasa:Number of samples in data = 2181058
# INFO:yasa:Sampling frequency = 100.00 Hz
# INFO:yasa:Data duration = 21810.58 seconds
# INFO:yasa:Trimmed standard deviation of CHAN000 = 20.6485 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN000 = 4660.3770 uV
# INFO:yasa:Trimmed standard deviation of CHAN001 = 17.9120 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN001 = 4069.6061 uV
# INFO:yasa:Trimmed standard deviation of CHAN002 = 23.5062 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN002 = 4851.8518 uV
# INFO:yasa:Trimmed standard deviation of CHAN003 = 27.3139 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN003 = 3987.3490 uV
# INFO:yasa:Trimmed standard deviation of CHAN004 = 20.1100 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN004 = 3914.2716 uV
# INFO:yasa:Trimmed standard deviation of CHAN005 = 21.0380 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN005 = 3805.6362 uV
# INFO:yasa:Trimmed standard deviation of CHAN006 = 19.9495 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN006 = 4169.8010 uV
# INFO:yasa:Trimmed standard deviation of CHAN007 = 20.3632 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN007 = 5292.4709 uV
# INFO:yasa:Trimmed standard deviation of CHAN008 = 22.7211 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN008 = 6208.8787 uV
# INFO:yasa:Number of channels in data = 9
# INFO:yasa:Number of samples in data = 2181058
# INFO:yasa:Sampling frequency = 100.00 Hz
# INFO:yasa:Data duration = 21810.58 seconds
# INFO:yasa:Number of epochs = 4362
# INFO:yasa:Artifact window = 5.00 seconds
# INFO:yasa:Method = covar
# INFO:yasa:Threshold = 3.00 standard deviations
# INFO:yasa:Stage 1: 4 / 132 epochs rejected (3.03%)
# INFO:yasa:Stage 2: 17 / 1895 epochs rejected (0.90%)
# INFO:yasa:Stage 3: 19 / 1074 epochs rejected (1.77%)
# INFO:yasa:Stage 4: 53 / 960 epochs rejected (5.52%)
# INFO:yasa:Rejecting 39 epochs with >=50% of channels that are flat. Z-scores set to np.nan for these epochs.
# INFO:yasa:TOTAL: 132 / 4362 epochs rejected (3.03%)
# ((4362,), (4362,))

# %%
art_up = yasa.hypno_upsample_to_data(art, sf_art, data, sf)

# Add -1 to hypnogram where artifacts were detected
hypno_with_art = hypno.copy()
hypno_with_art[art_up] = -1

yasa.plot_spectrogram(data[0, :], sf, hypno_with_art);
# Out:
# WARNING:yasa:Hypnogram is SHORTER than data by 0.58 seconds. Padding hypnogram with last value to match data.size.
# /usr/local/lib/python3.7/dist-packages/yasa/plotting.py:239: RuntimeWarning: divide by zero encountered in log10
#   Sxx = 10 * np.log10(Sxx)  # Convert uV^2 / Hz --> dB / Hz

# %% [markdown]
# ### 1.2. Standard-deviation based rejection

# %%
art_std, zscores_std = yasa.art_detect(data, sf, window=5, hypno=hypno, include=(1, 2, 3, 4), 
                                       method='std', threshold=3, verbose='info')

art_std.shape, zscores_std.shape
# Out:
# INFO:yasa:Number of unique values in hypno = 5
# INFO:yasa:Number of samples in data = 2181058
# INFO:yasa:Sampling frequency = 100.00 Hz
# INFO:yasa:Data duration = 21810.58 seconds
# INFO:yasa:Trimmed standard deviation of CHAN000 = 20.6485 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN000 = 4660.3770 uV
# INFO:yasa:Trimmed standard deviation of CHAN001 = 17.9120 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN001 = 4069.6061 uV
# INFO:yasa:Trimmed standard deviation of CHAN002 = 23.5062 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN002 = 4851.8518 uV
# INFO:yasa:Trimmed standard deviation of CHAN003 = 27.3139 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN003 = 3987.3490 uV
# INFO:yasa:Trimmed standard deviation of CHAN004 = 20.1100 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN004 = 3914.2716 uV
# INFO:yasa:Trimmed standard deviation of CHAN005 = 21.0380 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN005 = 3805.6362 uV
# INFO:yasa:Trimmed standard deviation of CHAN006 = 19.9495 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN006 = 4169.8010 uV
# INFO:yasa:Trimmed standard deviation of CHAN007 = 20.3632 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN007 = 5292.4709 uV
# INFO:yasa:Trimmed standard deviation of CHAN008 = 22.7211 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN008 = 6208.8787 uV
# INFO:yasa:Number of channels in data = 9
# INFO:yasa:Number of samples in data = 2181058
# INFO:yasa:Sampling frequency = 100.00 Hz
# INFO:yasa:Data duration = 21810.58 seconds
# INFO:yasa:Number of epochs = 4362
# INFO:yasa:Artifact window = 5.00 seconds
# INFO:yasa:Method = std
# INFO:yasa:Threshold = 3.00 standard deviations
# INFO:yasa:Stage 1: 8 / 132 epochs rejected (6.06%)
# INFO:yasa:Stage 2: 27 / 1895 epochs rejected (1.42%)
# INFO:yasa:Stage 3: 18 / 1074 epochs rejected (1.68%)
# INFO:yasa:Stage 4: 44 / 960 epochs rejected (4.58%)
# INFO:yasa:Rejecting 39 epochs with >=50% of channels that are flat. Z-scores set to np.nan for these epochs.
# INFO:yasa:TOTAL: 136 / 4362 epochs rejected (3.12%)
# ((4362,), (4362, 9))

# %%
art_up = yasa.hypno_upsample_to_data(art_std, sf_art, data, sf)

# Add -1 to hypnogram where artifacts were detected
hypno_with_art = hypno.copy()
hypno_with_art[art_up] = -1

yasa.plot_spectrogram(data[0, :], sf, hypno_with_art);
# Out:
# WARNING:yasa:Hypnogram is SHORTER than data by 0.58 seconds. Padding hypnogram with last value to match data.size.
# /usr/local/lib/python3.7/dist-packages/yasa/plotting.py:239: RuntimeWarning: divide by zero encountered in log10
#   Sxx = 10 * np.log10(Sxx)  # Convert uV^2 / Hz --> dB / Hz

# %%
print(f'The correlation between the two methods is r = {np.corrcoef(art, art_std)[0, 1]:.2f}')
# Out:
# The correlation between the two methods is r = 0.89

# %% [markdown]
# We can also apply a more conservative detection by specifying the number of channels that must be above or below threshold for the epoch to be marked as an artifact. In the code below, `n_chan_reject = 2` means that at least 2 channels must be above or below the threshold for the epoch to be marked as an artifact.

# %%
art_std, zscores_std = yasa.art_detect(data, sf, window=5, hypno=hypno, include=(1, 2, 3, 4), 
                                       method='std', threshold=3, n_chan_reject=2, verbose='info')
# Out:
# INFO:yasa:Number of unique values in hypno = 5
# INFO:yasa:Number of samples in data = 2181058
# INFO:yasa:Sampling frequency = 100.00 Hz
# INFO:yasa:Data duration = 21810.58 seconds
# INFO:yasa:Trimmed standard deviation of CHAN000 = 20.6485 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN000 = 4660.3770 uV
# INFO:yasa:Trimmed standard deviation of CHAN001 = 17.9120 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN001 = 4069.6061 uV
# INFO:yasa:Trimmed standard deviation of CHAN002 = 23.5062 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN002 = 4851.8518 uV
# INFO:yasa:Trimmed standard deviation of CHAN003 = 27.3139 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN003 = 3987.3490 uV
# INFO:yasa:Trimmed standard deviation of CHAN004 = 20.1100 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN004 = 3914.2716 uV
# INFO:yasa:Trimmed standard deviation of CHAN005 = 21.0380 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN005 = 3805.6362 uV
# INFO:yasa:Trimmed standard deviation of CHAN006 = 19.9495 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN006 = 4169.8010 uV
# INFO:yasa:Trimmed standard deviation of CHAN007 = 20.3632 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN007 = 5292.4709 uV
# INFO:yasa:Trimmed standard deviation of CHAN008 = 22.7211 uV
# INFO:yasa:Peak-to-peak amplitude of CHAN008 = 6208.8787 uV
# INFO:yasa:Number of channels in data = 9
# INFO:yasa:Number of samples in data = 2181058
# INFO:yasa:Sampling frequency = 100.00 Hz
# INFO:yasa:Data duration = 21810.58 seconds
# INFO:yasa:Number of epochs = 4362
# INFO:yasa:Artifact window = 5.00 seconds
# INFO:yasa:Method = std
# INFO:yasa:Threshold = 3.00 standard deviations
# INFO:yasa:Stage 1: 5 / 132 epochs rejected (3.79%)
# INFO:yasa:Stage 2: 17 / 1895 epochs rejected (0.90%)
# INFO:yasa:Stage 3: 15 / 1074 epochs rejected (1.40%)
# INFO:yasa:Stage 4: 27 / 960 epochs rejected (2.81%)
# INFO:yasa:Rejecting 39 epochs with >=50% of channels that are flat. Z-scores set to np.nan for these epochs.
# INFO:yasa:TOTAL: 103 / 4362 epochs rejected (2.36%)
