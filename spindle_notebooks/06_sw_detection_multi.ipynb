# %% [markdown]
# ##### install yasa

# %%
# !pip install --upgrade yasa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yasa
#   Downloading yasa-0.6.2.tar.gz (33.8 MB)
#      |████████████████████████████████| 33.8 MB 1.4 MB/s
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from yasa) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from yasa) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yasa) (1.3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from yasa) (3.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from yasa) (0.11.2)
# Collecting mne>=0.23
#   Downloading mne-1.1.1-py3-none-any.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 27.4 MB/s
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from yasa) (0.56.2)
# Collecting outdated
#   Downloading outdated-0.2.1-py3-none-any.whl (7.5 kB)
# Collecting antropy
#   Downloading antropy-0.1.4.tar.gz (16 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from yasa) (1.0.2)
# Collecting tensorpac>=0.6.5
#   Downloading tensorpac-0.6.5-py3-none-any.whl (423 kB)
#      |████████████████████████████████| 423 kB 5.8 MB/s
# Collecting pyriemann>=0.2.7
#   Downloading pyriemann-0.3.tar.gz (365 kB)
#      |████████████████████████████████| 365 kB 44.6 MB/s
# Collecting sleepecg>=0.5.0
#   Downloading sleepecg-0.5.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      |████████████████████████████████| 67 kB 3.7 MB/s
# Collecting lspopt
#   Downloading lspopt-1.2.0-py2.py3-none-any.whl (35 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from yasa) (7.7.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from yasa) (1.1.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.7/dist-packages (from mne>=0.23->yasa) (1.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from mne>=0.23->yasa) (2.11.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mne>=0.23->yasa) (21.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from mne>=0.23->yasa) (4.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from mne>=0.23->yasa) (4.64.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne>=0.23->yasa) (2.23.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne>=0.23->yasa) (1.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mne>=0.23->yasa) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.23->yasa) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.23->yasa) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.23->yasa) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.23->yasa) (2022.6.15)
# Requirement already satisfied: PyYAML>=5.4.0 in /usr/local/lib/python3.7/dist-packages (from sleepecg>=0.5.0->yasa) (6.0)
# Collecting requests>=2.19.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.4 MB/s
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.23->yasa) (2.1.1)
# Collecting stochastic
#   Downloading stochastic-0.6.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 3.1 MB/s
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (7.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (3.6.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->yasa) (3.0.3)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->yasa) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->yasa) (5.1.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (2.6.1)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 33.4 MB/s
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (57.4.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->yasa) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->yasa) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->yasa) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->yasa) (1.15.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->yasa) (5.3.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (1.8.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (5.4.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (5.6.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (4.11.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.13.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->yasa) (23.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->yasa) (2.8.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->mne>=0.23->yasa) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->yasa) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->yasa) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib->yasa) (4.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (5.0.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (2.16.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (4.3.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (5.9.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (22.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (4.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (3.8.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->yasa) (0.5.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->yasa) (0.39.1)
# Collecting littleutils
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yasa) (2022.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->yasa) (3.1.0)
# Building wheels for collected packages: yasa, pyriemann, antropy, littleutils
#   Building wheel for yasa (setup.py) ... done
#   Created wheel for yasa: filename=yasa-0.6.2-py3-none-any.whl size=33797167 sha256=e5adf76e732e1b62c8335118c4aa8082ed3937d6d35d7e9b669403c24fbdf1cf
#   Stored in directory: /root/.cache/pip/wheels/52/8c/9c/1352fced5b6240ed1e3669f477d7ce0e2fe693e28b7bcc45f4
#   Building wheel for pyriemann (setup.py) ... done
#   Created wheel for pyriemann: filename=pyriemann-0.3-py2.py3-none-any.whl size=78033 sha256=7b95103f40bca5a72812a657062795617463dbd2b0159beffa5a62b989567ac9
#   Stored in directory: /root/.cache/pip/wheels/0b/1b/bf/a537f9e17e6c3490004ede419c72f863af1d0d765d25e532ef
#   Building wheel for antropy (setup.py) ... done
#   Created wheel for antropy: filename=antropy-0.1.4-py3-none-any.whl size=16159 sha256=34d9f903b58595062e20bb5141ccb0b88e4f8ab3dbf6c35ca73aa48583eb7034
#   Stored in directory: /root/.cache/pip/wheels/d4/cc/6b/28fa7036bdabc6f1f92fd6a108ae259dbb48f107f676d6b491
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7048 sha256=00692764ec52705ab198d999a8df1846c9887cec503fb0bcf9514db4bb3c13fc
#   Stored in directory: /root/.cache/pip/wheels/d6/64/cd/32819b511a488e4993f2fab909a95330289c3f4e0f6ef4676d
# Successfully built yasa pyriemann antropy littleutils
# Installing collected packages: jedi, requests, stochastic, littleutils, tensorpac, sleepecg, pyriemann, outdated, mne, lspopt, antropy, yasa
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed antropy-0.1.4 jedi-0.18.1 littleutils-0.2.2 lspopt-1.2.0 mne-1.1.1 outdated-0.2.1 pyriemann-0.3 requests-2.28.1 sleepecg-0.5.0 stochastic-0.6.0 tensorpac-0.6.5 yasa-0.6.2

# %% [markdown]
# # Multi-channel slow-wave detection
#
# This notebook demonstrates how to use YASA to perform **multi-channel slow-waves detection** from a NumPy array (example 1) or a MNE Raw object (example 2). If you haven't done so already, check out the notebook on [single-channel slow-waves detection](05_sw_detection.ipynb).
#
# Please make sure to install the latest version of YASA first by typing the following line in your terminal or command prompt:
#
# `pip install --upgrade yasa`
#
# **Important**
# - The data must be a numpy array of shape *(n_channels, n_samples)*.
# - The sampling frequency `sf` must be the same for all channels.
# - A list of the channel names (`ch_names`) must be provided as well.
# - The unit of the data must be $\mu V$.
#
# ## Example 1: Using NumPy
#
# To illustrate the multi-channel slow-waves detection, we load a full-night 3-channels dataset (Cz, Fz, Pz) sampled at 100 Hz. The data is in compressed NumPy format (*.npz*).

# %%
#구글드라이브 공유폴더에서 불러오기
# !gdown --id 1z7uUvoDxHQhCCnIu48RwWspQy9mRRouV --output 02_data_full_6hrs_100Hz_Cz+Fz+Pz.npz
# !gdown --id 1scqMWfHpqdXQ4tyPfmfgTelHxh0xXg0J --output 05_data_full_6hrs_100Hz_hypno.npz
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1z7uUvoDxHQhCCnIu48RwWspQy9mRRouV
# To: /content/02_data_full_6hrs_100Hz_Cz+Fz+Pz.npz
# 100% 14.7M/14.7M [00:00<00:00, 161MB/s]
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1scqMWfHpqdXQ4tyPfmfgTelHxh0xXg0J
# To: /content/05_data_full_6hrs_100Hz_hypno.npz
# 100% 8.99k/8.99k [00:00<00:00, 9.53MB/s]

# %%
import mne
import yasa
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
f = np.load('/content/02_data_full_6hrs_100Hz_Cz+Fz+Pz.npz')
data, chan = f['data'], f['chan']
hypno = np.load('/content/05_data_full_6hrs_100Hz_hypno.npz').get('hypno')
sf = 100.
times = np.arange(data.size) / sf

print(data.shape, chan)
# Out:
# (3, 2161058) ['Cz' 'Fz' 'Pz']

# %% [markdown]
# To apply the multi-channel detection, we use the [sw_detect](https://raphaelvallat.com/yasa/build/html/generated/yasa.spindles_detect.html#yasa.spindles_detect) function. Note that we pass the hypnogram and restrain the detection to N2 or N3 sleep.

# %%
sw = yasa.sw_detect(data, sf, ch_names=chan, hypno=hypno, include=(2, 3))

# Get the full detection dataframe
sw.summary().round(2)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.4s finished
#          Start   NegPeak  MidCrossing   PosPeak       End  Duration  \
# 0       529.48    529.78       530.02    530.23    530.48      1.00
# 1       644.28    644.54       644.76    644.96    645.15      0.87
# 2       645.15    645.37       645.59    645.82    646.03      0.88
# 3       646.03    646.26       646.45    646.68    646.88      0.85
# 4       646.88    647.08       647.29    647.48    647.71      0.83
# ...        ...       ...          ...       ...       ...       ...
# 6992  20499.71  20500.10     20500.38  20500.69  20501.05      1.34
# 6993  20501.05  20501.29     20501.51  20501.76  20502.05      1.00
# 6994  20523.82  20524.15     20524.36  20524.62  20524.99      1.17
# 6995  20525.61  20526.21     20526.49  20526.76  20527.36      1.75
# 6996  20532.91  20533.28     20533.66  20533.90  20534.18      1.27
#
#       ValNegPeak  ValPosPeak     PTP   Slope  Frequency  Stage Channel  \
# 0         -43.37       34.23   77.60  323.32       1.00      2      Cz
# 1         -59.70       47.28  106.98  486.29       1.15      2      Cz
# 2         -48.10       48.93   97.03  441.03       1.14      2      Cz
# 3         -53.67       70.08  123.74  651.28       1.18      2      Cz
# 4         -66.64       52.30  118.95  566.41       1.20      2      Cz
# ...          ...         ...     ...     ...        ...    ...     ...
# 6992      -78.05       80.09  158.14  564.79       0.75      2      Pz
# 6993      -41.65       45.12   86.77  394.42       1.00      2      Pz
# 6994      -64.73       92.05  156.78  746.59       0.85      2      Pz
# 6995      -80.46       52.00  132.47  473.10       0.57      2      Pz
# 6996      -52.14       28.16   80.30  211.32       0.79      2      Pz
#
#       IdxChannel
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 6992           2
# 6993           2
# 6994           2
# 6995           2
# 6996           2
#
# [6997 rows x 14 columns]

# %%
# Get the average per channel and stage
sw.summary(grp_chan=True, grp_stage=True, aggfunc='mean')
# Out:
#                Count    Density  Duration  ValNegPeak  ValPosPeak         PTP  \
# Stage Channel
# 2     Cz         477   3.019226  1.203354  -78.654530   57.765269  136.419800
#       Fz         416   2.633120  1.181635  -88.028501   56.238414  144.266915
#       Pz         416   2.633120  1.273101  -73.346148   57.200875  130.547023
# 3     Cz        1936  21.628264  1.156271  -76.036749   63.328056  139.364805
#       Fz        1884  21.047340  1.147707  -72.681406   60.168087  132.849492
#       Pz        1868  20.868594  1.173185  -78.509145   63.952058  142.461203
#
#                     Slope  Frequency
# Stage Channel
# 2     Cz       515.759692   0.883919
#       Fz       545.816723   0.900314
#       Pz       476.516677   0.836252
# 3     Cz       539.105399   0.921905
#       Fz       524.391816   0.924978
#       Pz       538.441727   0.908249

# %%
# Plot an average template of the detected slow-waves, centered around the negative peak
ax = sw.plot_average(center="NegPeak", time_before=0.4, 
                     time_after=0.8, palette="Set1")
ax.legend(frameon=False)
sns.despine()

# %%
# Same but grouped by stage, using the `hue="Stage"` input parameter (default is "Channel")
# Note that we're also disabling the time-consuming bootstrapped confidence 
# intervals with `ci=None`.
ax = sw.plot_average(center="NegPeak", hue="Stage", time_before=0.4, 
                     time_after=0.8, ci=None,
                     palette=["xkcd:cerulean", "xkcd:midnight blue"])
ax.legend(frameon=False)
sns.despine()

# %% [markdown]
# **Grouped by both stage and channel**
#
# While YASA does not directly support grouping by both channel and stage, it is possible with just a few lines of code.

# %%
# First, we need to get a long-format dataframe of peak-locked event.
df_sync = sw.get_sync_events(center="NegPeak", time_before=0.4, time_after=0.8)
df_sync
# Out:
#         Time Event  Amplitude  Stage Channel  IdxChannel
# 0      -0.40     0  11.871379      2      Cz           0
# 1      -0.39     0   7.850428      2      Cz           0
# 2      -0.38     0   6.414374      2      Cz           0
# 3      -0.37     0   8.616323      2      Cz           0
# 4      -0.36     0  14.647750      2      Cz           0
# ...      ...   ...        ...    ...     ...         ...
# 846632  0.76  2283  10.897506      2      Pz           2
# 846633  0.77  2283   7.598260      2      Pz           2
# 846634  0.78  2283   9.997711      2      Pz           2
# 846635  0.79  2283  17.296041      2      Pz           2
# 846636  0.80  2283  26.593912      2      Pz           2
#
# [846637 rows x 6 columns]

# %%
# Then we can use seaborn.lineplot to create the desired plot:
ax = sns.lineplot(data=df_sync, x="Time", y="Amplitude", hue="Channel", 
                  style="Stage", palette="Set1", ci=None, dashes=True)

sns.despine()

# %% [markdown]
# *************
#
# ## Example 2: Using a Raw object from MNE-Python
#
# This example demonstrates how to manipulate [MNE Raw object](https://mne-tools.github.io/stable/generated/mne.io.Raw.html#mne.io.Raw). The MNE package has several [functions](https://mne-tools.github.io/stable/python_reference.html#module-mne.io) to load the most standard EEG file formats (EDF, BrainVision, EEGLab, FieldTrip...).
#
# For the sake of this example, we'll load a PSG file encoded in the native MNE format (*.fif) using the [mne.io.read_raw_fif](https://martinos.org/mne/stable/generated/mne.io.read_raw_fif.html) function.

# %%
#구글드라이브 공유폴더에서 불러오기
# !gdown --id 1buB_5AFeoFSQc63hIn2LCfhdAHqR5-DX --output 02_sub-02_mne_raw.fif
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1buB_5AFeoFSQc63hIn2LCfhdAHqR5-DX
# To: /content/02_sub-02_mne_raw.fif
# 100% 10.8M/10.8M [00:00<00:00, 210MB/s]

# %%
# Load the raw object
raw = mne.io.read_raw_fif('/content/02_sub-02_mne_raw.fif', preload=True, verbose=False)

# %%
# Let's have a look at the data
print('Chan =', raw.ch_names)
print('Sampling frequency =', raw.info['sfreq'])
print('Data shape =', raw._data.shape)
# Out:
# Chan = ['F3', 'F4', 'C3', 'C4', 'O1', 'O2', 'EOG1', 'EOG2', 'EMG1']
# Sampling frequency = 100.0
# Data shape = (9, 294000)

# %%
# Keep only the channels of interests
raw_eeg = raw.copy().pick_types(eeg=True).drop_channels(['O1', 'O2'])
print('Chan =', raw_eeg.ch_names)
# Out:
# Chan = ['F3', 'F4', 'C3', 'C4']

# %%
# Multi-channel slow-waves detection
# Note that since we're using a MNE Raw object, there is no need
# to manually specify the sampling frequency and channel names.
# We also use a less conservative amplitude threshold
sw = yasa.sw_detect(raw_eeg, amp_ptp=(50, 400))
print(sw.summary().shape[0], 'slow-waves detected.')
sw.summary().round(3)
# Out:
# 282 slow-waves detected.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s finished
#        Start  NegPeak  MidCrossing  PosPeak      End  Duration  ValNegPeak  \
# 0       0.40     0.60         0.83     0.98     1.16      0.76     -51.950
# 1      15.30    15.77        16.01    16.26    16.54      1.24     -81.465
# 2      38.53    38.78        38.97    39.20    39.44      0.91     -64.282
# 3     137.70   137.99       138.29   138.49   139.21      1.51     -63.788
# 4     196.51   196.81       197.04   197.31   197.71      1.20     -46.628
# ..       ...      ...          ...      ...      ...       ...         ...
# 277  2842.07  2842.45      2842.73  2842.94  2843.13      1.06     -65.999
# 278  2843.13  2843.35      2843.54  2843.78  2844.01      0.88     -53.510
# 279  2844.75  2845.03      2845.36  2845.89  2846.17      1.42    -124.029
# 280  2846.17  2846.39      2846.64  2846.80  2847.00      0.83     -77.389
# 281  2899.10  2899.53      2899.79  2900.04  2900.63      1.53     -62.844
#
#      ValPosPeak      PTP    Slope  Frequency Channel  IdxChannel
# 0        24.293   76.243  331.493      1.316      F3           0
# 1        96.554  178.019  741.746      0.806      F3           0
# 2        80.737  145.019  763.255      1.099      F3           0
# 3        24.904   88.691  295.638      0.662      F3           0
# 4        51.581   98.209  426.996      0.833      F3           0
# ..          ...      ...      ...        ...     ...         ...
# 277      46.460  112.459  401.638      0.943      C4           3
# 278      68.652  122.162  642.959      1.136      C4           3
# 279      99.849  223.878  678.417      0.704      C4           3
# 280      34.250  111.639  446.554      1.205      C4           3
# 281      55.791  118.635  456.289      0.654      C4           3
#
# [282 rows x 13 columns]

# %%
sw.summary(grp_chan=True)
# Out:
#          Count  Duration  ValNegPeak  ValPosPeak         PTP       Slope  \
# Channel
# C3          48  1.100000  -65.586750   49.535053  115.121803  452.410610
# C4          54  1.115370  -79.181103   57.808133  136.989236  548.546712
# F3         100  1.129200  -70.219874   53.856789  124.076663  486.470542
# F4          80  1.138375  -67.541603   50.583728  118.125331  457.817541
#
#          Frequency
# Channel
# C3        0.950368
# C4        0.956062
# F3        0.936939
# F4        0.940776

# %%
# Plot an average template of the detected slow-waves, centered around the start of the slow-wave
# Definitely noiser than our previous plot since there are fewer detected slow-waves
# in our second datset, because it's a 45 min nap and not a full-night recording!
ax = sw.plot_average(center="Start", time_before=0.2, time_after=1)
ax.legend(frameon=False)
sns.despine()

# %%
# !pip install ipympl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ipympl
#   Downloading ipympl-0.9.2-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 3.2 MB/s
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.7/dist-packages (from ipympl) (7.7.1)
# Requirement already satisfied: ipython<9 in /usr/local/lib/python3.7/dist-packages (from ipympl) (7.9.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from ipympl) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ipympl) (1.21.6)
# Requirement already satisfied: traitlets<6 in /usr/local/lib/python3.7/dist-packages (from ipympl) (5.1.1)
# Collecting matplotlib<4,>=3.4.0
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 57.1 MB/s
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from ipympl) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython<9->ipympl) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython<9->ipympl) (2.6.1)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.7/dist-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython<9->ipympl) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython<9->ipympl) (4.4.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.6.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.2-py3-none-any.whl (959 kB)
#      |████████████████████████████████| 959 kB 54.5 MB/s
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib<4,>=3.4.0->ipympl) (4.1.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython<9->ipympl) (1.15.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.3.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.4.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.11.3)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (23.2.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.16.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (22.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.12.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.9.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.8.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Installing collected packages: fonttools, matplotlib, ipympl
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# Successfully installed fonttools-4.37.2 ipympl-0.9.2 matplotlib-3.5.3

# %%
# Visual inspection of the detected slow-waves
# %matplotlib widget
# sw.plot_detection();
